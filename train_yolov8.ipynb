# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir /content/drive/MyDrive/dev/MPU/yolov8/data

# %%
# !unzip -qq /content/drive/MyDrive/target.v1i.yolov8.zip -d /content/drive/MyDrive/dev/MPU/yolov8/data

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.8/778.8 kB 13.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8s.pt')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 297MB/s]

# %%
model.train(data='/content/drive/MyDrive/dev/MPU/yolov8/train.yaml' , epochs=30)
# Out:
# Ultralytics YOLOv8.2.25 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import os
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt
# %matplotlib inline


# model = YOLO('yolov8s.pt')

model = YOLO('/content/runs/detect/train2/weights/best.pt')
files = os.listdir("/content/drive/MyDrive/dev/MPU/yolov8/data/test/images")
for f in files:
    results = model(f'/content/drive/MyDrive/dev/MPU/yolov8/data/test/images/{f}') # conf=0.2, iou ..

    plots = results[0].plot()

    plt.imshow(plots)
    plt.show()
# Out:
# image 1/1 /content/drive/MyDrive/dev/MPU/yolov8/data/test/images/WIN_20240528_21_11_17_Pro_jpg.rf.e0afca2a6c8627c454eaf3e8d07abc4b.jpg: 480x640 1 enemy, 177.5ms
# Speed: 2.6ms preprocess, 177.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# image 1/1 /content/drive/MyDrive/dev/MPU/yolov8/data/test/images/WIN_20240528_21_11_42_Pro-3-_jpg.rf.084b69d8854d53190612eb3cad8e7305.jpg: 480x640 1 enemy, 13.1ms
# Speed: 1.6ms preprocess, 13.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# image 1/1 /content/drive/MyDrive/dev/MPU/yolov8/data/test/images/WIN_20240528_21_13_27_Pro_jpg.rf.00a10f4fdb1050d756368b3b60ba9c2e.jpg: 480x640 1 friendly, 13.1ms
# Speed: 1.5ms preprocess, 13.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# image 1/1 /content/drive/MyDrive/dev/MPU/yolov8/data/test/images/WIN_20240528_21_13_28_Pro_jpg.rf.ab8ea7ce1a11c394e6d757dc5cfeac8f.jpg: 480x640 1 friendly, 13.1ms
# ...
